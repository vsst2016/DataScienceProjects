# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import func as f

# %matplotlib inline

# %%
# Load the data into pandas dataframe 
df_2018 = pd.read_csv('data/2018/survey_results_public.csv',low_memory=False);
schema_2018 =pd.read_csv('data/2018/survey_results_schema.csv');
df_2018.head()
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# ...

# %%
schema_2018.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1       Hobby                            Do you code as a hobby?
# 2  OpenSource         Do you contribute to open source projects?
# 3     Country          In which country do you currently reside?
# 4     Student  Are you currently enrolled in a formal, degree...

# %% [markdown]
# # Hackathon

# %%
# get the description of the HackathonReasons column
f.get_description('HackathonReasons')
# Out:
# 'You indicated previously that you had participated in an online coding competition or hackathon.  Which of the following best describe your reasons for doing so?'

# %%
# different values of the HackathonReasons columns
df_2018.HackathonReasons.value_counts()
# Out:
# To improve my general technical skills or programming ability;To improve my knowledge of a specific programming language, framework, or other technology;Because I find it enjoyable                                                                                                                                                                       3160
# Because I find it enjoyable                                                                                                                                                                                                                                                                                                                                3048
# ...

# %%
# Unique Values in HackathonReasons Column using unique_vals function written in func.py
pos_hac_vals = f.unique_vals(df_2018,'HackathonReasons')
pos_hac_vals
# Out:
# ['To build my professional network',
#  'To improve my general technical skills or programming ability',
#  'To improve my knowledge of a specific programming language, framework, or other technology',
#  'Because I find it enjoyable',
#  'To improve my ability to work on a team with other programmers',
#  'To help me find new job opportunities',
#  'To win prizes or cash awards']

# %%
# Clean and plot values of HackathonReasons column  using clean_and_plot function written in func.py
f.clean_and_plot(df_2018,'HackathonReasons',pos_hac_vals,'Hackathon Reasons',True)
# Out:
#                                                        count
# HackathonReasons
# Because I find it enjoyable                         0.262341
# To improve my general technical skills or progr...  0.227396
# To improve my knowledge of a specific programmi...  0.176184
# To improve my ability to work on a team with ot...  0.103041
# To build my professional network                    0.094552
# To help me find new job opportunities               0.071563
# To win prizes or cash awards                        0.064923
